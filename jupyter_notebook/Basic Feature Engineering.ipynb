# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re
from collections import Counter
pd.pandas.set_option('display.max_columns',None)

# %%
train_data = pd.read_csv("../data/train.csv")
train_data.shape
# Out:
# (1460, 81)

# %%
train_data.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
test_data = pd.read_csv("../data/test.csv")
test_data.shape
# Out:
# (1459, 80)

# %%
test_data.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1454         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1455         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1456         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1458         Lvl    AllPub    Inside       Mod      Mitchel       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
combined_data = pd.concat([train_data,test_data]).reset_index(drop=True)

# %%
combined_data.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 2914  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2915  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2916  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2917  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 2918  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 2914         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 2915         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 2916         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 2917         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 2918         Lvl    AllPub    Inside       Mod      Mitchel       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ### Removing the Missing Value that is Greater than 30%

# %%
def detect_Missingvalue(df,features=None,Percentage=70):
    features = features if features != None else df.columns
    data = (df[features].isnull().sum()/df[features].shape[0])*100 > Percentage
    return df[[feature[0] for feature in data.items() if feature[1]]].columns

# %%
lst = [feature for feature in combined_data.columns if feature != 'SalePrice']
print(detect_Missingvalue(combined_data,lst,30))
# Out:
# Index(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')

# %%
combined_data.drop(detect_Missingvalue(combined_data,lst,30),axis=1, inplace=True)

# %%
print(detect_Missingvalue(combined_data,None,30))
# Out:
# Index(['SalePrice'], dtype='object')

# %% [markdown]
# ### Removing the Zero Variance from the data

# %%
def zerovariance_detection(data, features=None):
    columns = []
    zero_variance_variables = []
    columns = features if features != None else data.columns  
    for variable in columns:
        if data[variable].dtypes != 'O':
            if (data[variable].std() == 0):
                zero_variance_variables.append(variable)
    return zero_variance_variables

# %%
print(zerovariance_detection(combined_data))
# Out:
# []

# %% [markdown]
# ### Filling the Missing Values

# %%
categorical_nan_data = [feature for feature in combined_data.columns if combined_data[feature].dtypes =='O' and feature != 'SalePrice' and combined_data[feature].isnull().sum()>=1 ]
categorical_nan_data
# Out:
# ['MSZoning',
#  'Utilities',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'SaleType']

# %%
numerical_nan_data = [feature for feature in combined_data.columns if combined_data[feature].dtypes !='O'and feature != 'SalePrice'and combined_data[feature].isnull().sum()>=1]
numerical_nan_data
# Out:
# ['LotFrontage',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea']

# %%
## Replace missing value with a new label
def replace_cat_feature(dataset,features_nan):
    data=dataset.copy()
    for feature in features_nan:
        print(f" {feature} => {data[feature].mode()[0]}")
        data[feature]=data[feature].fillna(data[feature].mode()[0])
    return data

# %%
combined_data = replace_cat_feature(combined_data,categorical_nan_data)
# Out:
#  MSZoning => RL
#  Utilities => AllPub
#  Exterior1st => VinylSd
#  Exterior2nd => VinylSd
#  MasVnrType => None
#  BsmtQual => TA
#  BsmtCond => TA
#  BsmtExposure => No
#  BsmtFinType1 => Unf
#  BsmtFinType2 => Unf
#  Electrical => SBrkr
#  KitchenQual => TA
#  Functional => Typ
#  GarageType => Attchd
#  GarageFinish => Unf
#  GarageQual => TA
#  GarageCond => TA
#  SaleType => WD

# %%
def replace_num_feature(dataset,features_nan):
    data=dataset.copy()
    for feature in features_nan:
        print(f" {feature} => {data[feature].median()}")
        data[feature]=data[feature].fillna(data[feature].median())
    return data

# %%
combined_data = replace_num_feature(combined_data,numerical_nan_data)
# Out:
#  LotFrontage => 68.0
#  MasVnrArea => 0.0
#  BsmtFinSF1 => 368.5
#  BsmtFinSF2 => 0.0
#  BsmtUnfSF => 467.0
#  TotalBsmtSF => 989.5
#  BsmtFullBath => 0.0
#  BsmtHalfBath => 0.0
#  GarageYrBlt => 1979.0
#  GarageCars => 2.0
#  GarageArea => 480.0

# %%
categorical_nan_data = [feature for feature in combined_data.columns if combined_data[feature].dtypes =='O' and feature != 'SalePrice' and combined_data[feature].isnull().sum()>=1 ]
print(categorical_nan_data)
numerical_nan_data = [feature for feature in combined_data.columns if combined_data[feature].dtypes !='O'and feature != 'SalePrice'and combined_data[feature].isnull().sum()>=1]
print(numerical_nan_data)
# Out:
# []
# []

# %%
for feature in ['YearBuilt','YearRemodAdd','GarageYrBlt']:
    combined_data[feature]=combined_data['YrSold']-train_data[feature]

# %%
combined_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
categorical_features = [feature for feature in combined_data if combined_data[feature].dtypes =='O']

# %%
for feature in categorical_features:
    labels_ordered=combined_data.groupby([feature])['Id'].mean().sort_values().index
    labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
    combined_data[feature]=combined_data[feature].map(labels_ordered)

# %%
combined_data.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0   1          60         2         65.0     8450       1         3
# 1   2          20         2         80.0     9600       1         3
# 2   3          60         2         68.0    11250       1         2
# 3   4          70         2         60.0     9550       1         2
# 4   5          60         2         84.0    14260       1         2
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0            2          1          3          2            10           3
# 1            2          1          0          2             8           4
# 2            2          1          3          2            10           3
# 3            2          1          1          2            20           3
# 4            2          1          0          2             4           3
#
#    Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
feature_scale=[feature for feature in combined_data.columns if feature not in ['Id','SalePrice']]

# %%
from sklearn.preprocessing import MinMaxScaler
combined_data_scaler=MinMaxScaler() # feature_range=(0, 1)
combined_data_scaler.fit(combined_data[feature_scale])
# Out:
# MinMaxScaler()

# %%
combined_data_scaler.transform(combined_data[feature_scale])
# Out:
# array([[0.23529412, 0.5       , 0.15068493, ..., 0.5       , 0.5       ,
#         0.4       ],
#        [0.        , 0.5       , 0.20205479, ..., 0.25      , 0.5       ,
#         0.4       ],
#        [0.23529412, 0.5       , 0.1609589 , ..., 0.5       , 0.5       ,
#         0.4       ],
#        ...,
#        [0.        , 0.5       , 0.4760274 , ..., 0.        , 0.5       ,
#         0.2       ],
#        [0.38235294, 0.5       , 0.14041096, ..., 0.        , 0.5       ,
#         0.4       ],
#        [0.23529412, 0.5       , 0.18150685, ..., 0.        , 0.5       ,
#         0.4       ]])

# %%
combined_processed_data = pd.concat([combined_data[['Id', 'SalePrice']].reset_index(drop=True),
                    pd.DataFrame(combined_data_scaler.transform(combined_data[feature_scale]), columns=feature_scale)],
                    axis=1)

# %%
combined_processed_data.head()
# Out:
#    Id  SalePrice  MSSubClass  MSZoning  LotFrontage   LotArea  Street  \
# 0   1   208500.0    0.235294       0.5     0.150685  0.033420     1.0
# 1   2   181500.0    0.000000       0.5     0.202055  0.038795     1.0
# 2   3   223500.0    0.235294       0.5     0.160959  0.046507     1.0
# 3   4   140000.0    0.294118       0.5     0.133562  0.038561     1.0
# 4   5   250000.0    0.235294       0.5     0.215753  0.060576     1.0
#
#    LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# 0  1.000000     0.666667        1.0       0.75        1.0      0.416667
# 1  1.000000     0.666667        1.0       0.00        1.0      0.333333
# 2  0.666667     0.666667        1.0       0.75        1.0      0.416667
# 3  0.666667     0.666667        1.0       0.25        1.0      0.833333
# 4  0.666667     0.666667        1.0       0.00        1.0      0.166667
#
#    Condition1  Condition2  BldgType  HouseStyle  OverallQual  OverallCond  \
# ...

# %%
def coorilation_detection(data, features = None):
    corrmat = data.corr()
    columns = features if features != None else [ i for i in data.columns if (data[i].dtype in ['int32','int64','float32','float64'] ) ]
    coorilated_variables = {}
    for variable in columns:
        for variable1 in columns:
            if variable == variable1:
                continue
            elif abs(corrmat[variable][variable1]) >= 0.75:
                if ((variable not in coorilated_variables.keys()) and 
                    (variable1 not in coorilated_variables.keys())): 
                    coorilated_variables[variable] = []
                    coorilated_variables[variable].append(variable1)
                elif (variable1 not in coorilated_variables.keys()):  
                    coorilated_variables[variable].append(variable1)
    return coorilated_variables

# %%
lst = [i for i in combined_processed_data.columns if (i != 'SalePrice' and combined_processed_data[i].dtypes != 'O')]
coorilation_detection(combined_processed_data, lst)
# Out:
# {'YearBuilt': ['GarageYrBlt'],
#  'TotalBsmtSF': ['1stFlrSF'],
#  'GrLivArea': ['TotRmsAbvGrd'],
#  'GarageCars': ['GarageArea']}

# %%
combined_processed_data.drop(['GarageYrBlt', '1stFlrSF', 'TotRmsAbvGrd', 'GarageCars'],axis=1,inplace=True)

# %%
combined_processed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2919 entries, 0 to 2918
# Data columns (total 72 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2919 non-null   int64
#  1   SalePrice      1460 non-null   float64
#  2   MSSubClass     2919 non-null   float64
#  3   MSZoning       2919 non-null   float64
#  4   LotFrontage    2919 non-null   float64
#  5   LotArea        2919 non-null   float64
#  6   Street         2919 non-null   float64
#  7   LotShape       2919 non-null   float64
#  8   LandContour    2919 non-null   float64
#  9   Utilities      2919 non-null   float64
#  10  LotConfig      2919 non-null   float64
#  11  LandSlope      2919 non-null   float64
#  12  Neighborhood   2919 non-null   float64
#  13  Condition1     2919 non-null   float64
#  14  Condition2     2919 non-null   float64
#  15  BldgType       2919 non-null   float64
#  16  HouseStyle     2919 non-null   float64
# ...

# %%
combined_processed_data.drop(['YearBuilt', 'YearRemodAdd'],axis=1,inplace=True)

# %%
train_processed_data = combined_processed_data.iloc[:1460]
test_processed_data = combined_processed_data.iloc[1460:]

# %%
train_processed_data.tail()
# Out:
#         Id  SalePrice  MSSubClass  MSZoning  LotFrontage   LotArea  Street  \
# 1455  1456   175000.0    0.235294       0.5     0.140411  0.030929     1.0
# 1456  1457   210000.0    0.000000       0.5     0.219178  0.055505     1.0
# 1457  1458   266500.0    0.294118       0.5     0.154110  0.036187     1.0
# 1458  1459   142125.0    0.000000       0.5     0.160959  0.039342     1.0
# 1459  1460   147500.0    0.000000       0.5     0.184932  0.040370     1.0
#
#       LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# 1455       1.0     0.666667        1.0       0.75        1.0      0.375000
# 1456       1.0     0.666667        1.0       0.75        1.0      0.083333
# 1457       1.0     0.666667        1.0       0.75        1.0      0.833333
# 1458       1.0     0.666667        1.0       0.75        1.0      0.458333
# 1459       1.0     0.666667        1.0       0.75        1.0      0.791667
#
# ...

# %%
test_processed_data.tail()
# Out:
#         Id  SalePrice  MSSubClass  MSZoning  LotFrontage   LotArea  Street  \
# 2914  2915        NaN    0.823529      0.75     0.000000  0.002973     1.0
# 2915  2916        NaN    0.823529      0.75     0.000000  0.002776     1.0
# 2916  2917        NaN    0.000000      0.50     0.476027  0.087406     1.0
# 2917  2918        NaN    0.382353      0.50     0.140411  0.042726     1.0
# 2918  2919        NaN    0.235294      0.50     0.181507  0.038921     1.0
#
#       LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# 2914       1.0     0.666667        1.0       0.75        1.0      0.916667
# 2915       1.0     0.666667        1.0       0.75        1.0      0.916667
# 2916       1.0     0.666667        1.0       0.75        1.0      0.875000
# 2917       1.0     0.666667        1.0       0.75        1.0      0.875000
# 2918       1.0     0.666667        1.0       0.75        0.5      0.875000
#
# ...

# %%
test_processed_data.drop(["SalePrice"], axis=1, inplace=True)
test_processed_data.to_csv('../data/new_test_processed_data.csv',index=False)
# Out:
# c:\users\melwin\.conda\envs\tutorialdatascience\lib\site-packages\pandas\core\frame.py:4160: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
train_processed_data.to_csv('../data/new_train_processed_data.csv',index=False)
